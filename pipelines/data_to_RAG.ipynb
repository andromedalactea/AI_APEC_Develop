# %% [markdown]
# Install Required Libraries

# %%
# !pip install -q -r ../requirements_pipelines.txt

# %% [markdown]
# Import Required Libraries

# %%
# Python Libraries
import os
from collections import Counter, defaultdict
from IPython.display import display, clear_output
import time

# External Libraries
import numpy as np

# %% [markdown]
# Initial Analize of the data

# %%
# Ruta base de la unidad montada en WSL
base_path = '/mnt/i'

# Inicializamos un contador para las extensiones y un diccionario para tamaños
file_types = Counter()
file_sizes = defaultdict(int)  # Usaremos un defaultdict para acumular los tamaños

# Función para mostrar resultados parciales
def mostrar_resultados_parciales(file_types, file_sizes):
    clear_output(wait=True)  # Limpiamos la salida para actualizar
    print("Conteo de archivos y tamaño por extensión (actualizado):")
    for ext, count in file_types.items():
        size_in_mb = file_sizes[ext] / (1024 * 1024)  # Convertir tamaño a MB
        print(f"{ext}: {count} archivos, {size_in_mb:.2f} MB")

# Recorremos todas las carpetas y subcarpetas usando os.walk
for dirpath, dirnames, filenames in os.walk(base_path):
    for filename in filenames:
        # Extraer la extensión del archivo
        file_extension = os.path.splitext(filename)[1].lower()
        # Obtener la ruta completa del archivo
        file_path = os.path.join(dirpath, filename)
        
        try:
            # Obtener el tamaño del archivo
            file_size = os.path.getsize(file_path)
            # Contar la extensión y acumular el tamaño
            file_types[file_extension] += 1
            file_sizes[file_extension] += file_size
        except FileNotFoundError:
            # Si el archivo no está accesible o es eliminado mientras se recorre, ignorarlo
            continue
        
    # Mostrar resultados parciales después de cada directorio
    mostrar_resultados_parciales(file_types, file_sizes)
    time.sleep(0.1)  # Añadir una pequeña pausa para que la actualización sea más visible

# Mostrar resultados finales
print("Conteo final de archivos y tamaño por extensión:")
for ext, count in file_types.items():
    size_in_mb = file_sizes[ext] / (1024 * 1024)  # Convertir tamaño a MB
    print(f"{ext}: {count} archivos, {size_in_mb:.2f} MB")
# Out:
# Conteo de archivos y tamaño por extensión (actualizado):
# .pdf: 5027 archivos, 3622.27 MB
# .png: 536 archivos, 10.29 MB
# .txt: 441 archivos, 1.13 MB
# .ini: 7 archivos, 0.01 MB
# .log: 166 archivos, 0.77 MB
# .bin: 2 archivos, 981.39 MB
# .inf: 5 archivos, 0.00 MB
# .mky: 2 archivos, 0.00 MB
# .hv: 2 archivos, 0.44 MB
# .dll: 103 archivos, 18.80 MB
# .exe: 381 archivos, 33524.04 MB
# .cmd: 3 archivos, 0.00 MB
# .db: 70 archivos, 9.12 MB
# .sql: 54 archivos, 0.11 MB
# .pem: 1 archivos, 0.00 MB
# .xml: 817 archivos, 20.09 MB
# .tim: 1 archivos, 0.00 MB
# .tim2: 1 archivos, 0.00 MB
# .cfg: 5 archivos, 0.00 MB
# .dtl: 1 archivos, 0.00 MB
# .___: 1 archivos, 0.41 MB
# .xsl: 3 archivos, 0.00 MB
# .css: 6 archivos, 1.09 MB
# .bmp: 255 archivos, 0.78 MB
# .htm: 30 archivos, 0.30 MB
# .py: 2 archivos, 0.00 MB
# .pip: 18 archivos, 2.90 MB
# .asp: 227 archivos, 1.80 MB
# .swf: 431 archivos, 15.05 MB
# .gif: 58 archivos, 0.08 MB
# .js: 61 archivos, 3.28 MB
# : 15 archivos, 4.71 MB
# ...

# %%
import pandas as pd

df = pd.read_excel('/home/andromedalactea/freelance/AI_APEC_Develop/data/tabular/Test/APRINT OCT2018/Copy of Construction Crew Schedule Tracking.xlsx')

df
# Out:
# /home/andromedalactea/freelance/AI_APEC_Develop/.venv/lib/python3.10/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: '10-1 - 11-2'!$A:$Z.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /home/andromedalactea/freelance/AI_APEC_Develop/.venv/lib/python3.10/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: '2-19 - 3-2'!$A:$K.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /home/andromedalactea/freelance/AI_APEC_Develop/.venv/lib/python3.10/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: '3-5 - 3-30'!$A:$U.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /home/andromedalactea/freelance/AI_APEC_Develop/.venv/lib/python3.10/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: '4-2 - 4-27'!$A:$U.
# ...
